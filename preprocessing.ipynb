# %%
import geopandas as gpd
import pandas as pd
import glob
import os

# %% [markdown]
# ### Data
#
# - Corine Land Cover Colombia 2000-2002 (cover2000): https://www.colombiaenmapas.gov.co/?e=-91.07859485351392,-7.914089216137852,-57.41648547852286,17.909127410706898,4686&b=igac&u=0&t=43&servicio=878
# - Corine Land Cover Colombia 2010-2012 (cover2010): https://www.colombiaenmapas.gov.co/?e=-91.07859485351392,-7.914089216137852,-57.41648547852286,17.909127410706898,4686&b=igac&u=0&t=43&servicio=880
# - Corine Land Cover Colombia 2018 (cover2018):https://www.colombiaenmapas.gov.co/?e=-91.07859485351392,-7.914089216137852,-57.41648547852286,17.909127410706898,4686&b=igac&u=0&t=43&servicio=881
# - Colombia Departments: https://www.colombiaenmapas.gov.co/?e=-91.07859485351392,-7.914089216137852,-57.41648547852286,17.909127410706898,4686&b=igac&u=0&t=29&servicio=609
#
# Arauca, Casanare, and Meta boundaries were extracted from Colombia Departments with QGIS

# %% [markdown]
# ### Departments Land Cover

# %%
# Define input file paths
covers = {
    "cover2000": "./data/cover/cover_2000/cover_2000.shp",
    "cover2010": "./data/cover/cover_2010/cover_2010.shp",
    "cover2018": "./data/cover/cover_2018/cover_2018.shp"
}

departments = {
    "ara": "./data/departments/arauca.shp",
    "casa": "./data/departments/casanare.shp",
    "meta": "./data/departments/meta.shp"
}

# Convert shapefiles to GeoPackages
for name, path in covers.items():
    gdf = gpd.read_file(path)
    out_path = f"./data/cover/gpkg/{name}.gpkg"
    gdf.to_file(out_path, driver="GPKG")
    print(f"Land cover converted to GeoPackage: {out_path}")

for name, path in departments.items():
    gdf = gpd.read_file(path)
    out_path = f"./data/departments/{name}.gpkg"
    gdf.to_file(out_path, driver="GPKG")
    print(f"Department converted to GeoPackage: {out_path}")

# %%
# Clip land cover by department 
for dep_name in departments:
    dep_gdf = gpd.read_file(f"./data/departments/{dep_name}.gpkg")
    for cov_name in covers:
        cov_gdf = gpd.read_file(f"./data/cover/gpkg/{cov_name}.gpkg")

        # Perform spatial intersection (clip)
        clipped = gpd.overlay(cov_gdf, dep_gdf, how="intersection")

        # Save result
        out_name = f"{dep_name}_{cov_name}.gpkg"
        out_path = f"./data/cover/departments/{out_name}"
        clipped.to_file(out_path, driver="GPKG")

        print(f"Saved: {out_path}")
# Out:
# Saved: ./data/cover/departments/ara_cover2000.gpkg
# Saved: ./data/cover/departments/ara_cover2010.gpkg
# Saved: ./data/cover/departments/ara_cover2018.gpkg
# Saved: ./data/cover/departments/casa_cover2000.gpkg
# Saved: ./data/cover/departments/casa_cover2010.gpkg
# Saved: ./data/cover/departments/casa_cover2018.gpkg
# Saved: ./data/cover/departments/meta_cover2000.gpkg
# Saved: ./data/cover/departments/meta_cover2010.gpkg
# c:\Users\VICTUS\anaconda3\envs\osgeo-env-v1\lib\site-packages\ipykernel_launcher.py:8: UserWarning: `keep_geom_type=True` in overlay resulted in 1 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
# Saved: ./data/cover/departments/meta_cover2018.gpkg

# %% [markdown]
# Load departments land cover

# %%
covers_dir= "./data/cover/departments"

# Find all GPKG files in the folder
covers_dep_files = glob.glob(os.path.join(covers_dir, "*.gpkg"))

# Read them into a dictionary
covers_dep = {os.path.basename(f).replace(".gpkg", ""): gpd.read_file(f) for f in covers_dep_files}

# %% [markdown]
# Create a new column with Level 2 classes, and extract its respective code class. The new datasets will include three columns: Level 2 classes, Level 2 code, and geometry.

# %%
# Define the mapping from level 2 codes to their descriptions
level_2_mapping = {
    "1.1": "Urban",
    "1.2": "Industrial and commercial",
    "1.3": "Mine, dump and construction",
    "1.4": "Artificial non-agricultural vegetated areas",
    "2.1": "Arable land",
    "2.2": "Permanent crops",
    "2.3": "Pastures",
    "2.4": "Heterogeneous agricultural areas",
    "3.1": "Forest",
    "3.2": "Shrub or herbaceous vegetation",
    "3.3": "Little vegetated areas",
    "4.1": "Wetlands",
    "5.1": "Water bodies"
}

# Function to map level 3 to level 2 with number and class
def map_to_level_2(level_3_code):
    level_2_code = ".".join(level_3_code.split(".")[:2])  # Extract first two digits
    level_2_class = level_2_mapping.get(level_2_code, "Unknown")
    return f"{level_2_code} {level_2_class}"  # Combine number and class

def extract_level2_code(level2_str):
    code = level2_str.split()[0]  # Get '1.1'
    return code.replace('.', '')  # '1.1' -> '11'


# Output folder
output_folder = "./data/cover/coverl2"

# Process datasets
datasets = {
    "ara_cover2000l2": (covers_dep['ara_cover2000'], "LEYENDA"),
    "ara_cover2010l2": (covers_dep['ara_cover2010'], "LEYENDA3N"),
    "ara_cover2018l2": (covers_dep['ara_cover2018'], "leyenda"),
    "casa_cover2000l2": (covers_dep['casa_cover2000'], "LEYENDA"),
    "casa_cover2010l2": (covers_dep['casa_cover2010'], "LEYENDA3N"),
    "casa_cover2018l2": (covers_dep['casa_cover2018'], "leyenda"),
    "meta_cover2000l2": (covers_dep['meta_cover2000'], "LEYENDA"),
    "meta_cover2010l2": (covers_dep['meta_cover2010'], "LEYENDA3N"),
    "meta_cover2018l2": (covers_dep['meta_cover2018'], "leyenda")
}

# New dictionary to store processed Level 2 datasets
lc = {}

for dataset_name, (gdf, column_name) in datasets.items():
   
    # Reproject to EPSG:9377
    gdf = gdf.to_crs(9377)

    # Add a new column for level 2 categories
    gdf["level2"] = gdf[column_name].apply(map_to_level_2)

    # Add level2_code column
    gdf["l2_code"] = gdf["level2"].apply(extract_level2_code)
    
    # Keep only the Level_2 column and geometry
    gdf = gdf[["level2", "l2_code","geometry"]]
    
    # Store in dictionary
    lc[dataset_name] = gdf

    # Save the updated dataset
    output_path = os.path.join(output_folder, f"{dataset_name}.gpkg")
    gdf.to_file(output_path, driver="GPKG", layer=dataset_name)
    print(f"Processed {dataset_name} and saved to {output_path}")
# Out:
# Processed ara_cover2000l2 and saved to ./data/cover/coverl2\ara_cover2000l2.gpkg
# Processed ara_cover2010l2 and saved to ./data/cover/coverl2\ara_cover2010l2.gpkg
# Processed ara_cover2018l2 and saved to ./data/cover/coverl2\ara_cover2018l2.gpkg
# Processed casa_cover2000l2 and saved to ./data/cover/coverl2\casa_cover2000l2.gpkg
# Processed casa_cover2010l2 and saved to ./data/cover/coverl2\casa_cover2010l2.gpkg
# Processed casa_cover2018l2 and saved to ./data/cover/coverl2\casa_cover2018l2.gpkg
# Processed meta_cover2000l2 and saved to ./data/cover/coverl2\meta_cover2000l2.gpkg
# Processed meta_cover2010l2 and saved to ./data/cover/coverl2\meta_cover2010l2.gpkg
# Processed meta_cover2018l2 and saved to ./data/cover/coverl2\meta_cover2018l2.gpkg

# %% [markdown]
# ### Land Use Vocation

# %%
# Arauca 
ara_voc= gpd.read_file("./data/vocation/ara_voc.gpkg")

# Casanare
casa_voc= gpd.read_file("../data/vocation/casa_voc.gpkg")

# Meta
meta_voc= gpd.read_file("./data/vocation/meta_voc.gpkg")

# %% [markdown]
# ### Intersection: **Land Cover** and **Land Use Vocation**

# %%
# Perform the intersection
ara_lcvoc_2000 = gpd.overlay(lc['ara_cover2000l2'], ara_voc, how="intersection")

# Save the result to a file
output_path = "./data/lc_voc/ara_lcvoc_2000.gpkg"
ara_lcvoc_2000.to_file(output_path, driver="GPKG")
# Out:
# c:\Users\VICTUS\anaconda3\envs\osgeo-env-v1\lib\site-packages\ipykernel_launcher.py:2: UserWarning: `keep_geom_type=True` in overlay resulted in 81 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries

# %%
# Perform the intersection
ara_lcvoc_2010 = gpd.overlay(lc['ara_cover2010l2'], ara_voc, how="intersection")

# Save the result to a file
output_path = "./data/lc_voc/ara_lcvoc_2010.gpkg"
ara_lcvoc_2010.to_file(output_path, driver="GPKG")
# Out:
# c:\Users\VICTUS\anaconda3\envs\osgeo-env-v1\lib\site-packages\ipykernel_launcher.py:2: UserWarning: `keep_geom_type=True` in overlay resulted in 115 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries

# %%
# Perform the intersection
ara_lcvoc_2018 = gpd.overlay(lc['ara_cover2018l2'], ara_voc, how="intersection")

# Save the result to a file
output_path = "./data/lc_voc/ara_lcvoc_2018.gpkg"
ara_lcvoc_2018.to_file(output_path, driver="GPKG")
# Out:
# c:\Users\VICTUS\anaconda3\envs\osgeo-env-v1\lib\site-packages\ipykernel_launcher.py:2: UserWarning: `keep_geom_type=True` in overlay resulted in 9 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries

# %%
# Perform the intersection
casa_lcvoc_2000 = gpd.overlay(lc['casa_cover2000l2'], casa_voc, how="intersection")

# Save the result to a file
output_path = "./data/lc_voc/casa_lcvoc_2000.gpkg"
casa_lcvoc_2000.to_file(output_path, driver="GPKG")
# Out:
# c:\Users\VICTUS\anaconda3\envs\osgeo-env-v1\lib\site-packages\ipykernel_launcher.py:2: UserWarning: `keep_geom_type=True` in overlay resulted in 451 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries

# %%
# Perform the intersection
casa_lcvoc_2010 = gpd.overlay(lc['casa_cover2010l2'], casa_voc, how="intersection")

# Save the result to a file
output_path = "./data/lc_voc/casa_lcvoc_2010.gpkg"
casa_lcvoc_2010.to_file(output_path, driver="GPKG")
# Out:
# c:\Users\VICTUS\anaconda3\envs\osgeo-env-v1\lib\site-packages\ipykernel_launcher.py:2: UserWarning: `keep_geom_type=True` in overlay resulted in 970 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries

# %%
# Perform the intersection
casa_lcvoc_2018 = gpd.overlay(lc['casa_cover2018l2'], casa_voc, how="intersection")

# Save the result to a file
output_path = "./data/lc_voc/casa_lcvoc_2018.gpkg"
casa_lcvoc_2018.to_file(output_path, driver="GPKG")
# Out:
# c:\Users\VICTUS\anaconda3\envs\osgeo-env-v1\lib\site-packages\ipykernel_launcher.py:2: UserWarning: `keep_geom_type=True` in overlay resulted in 1179 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries

# %%
# Perform the intersection
meta_lcvoc_2000 = gpd.overlay(lc['meta_cover2000l2'], meta_voc, how="intersection")

# Save the result to a file
output_path = "./data/lc_voc/meta_lcvoc_2000.gpkg"
meta_lcvoc_2000.to_file(output_path, driver="GPKG")
# Out:
# c:\Users\VICTUS\anaconda3\envs\osgeo-env-v1\lib\site-packages\ipykernel_launcher.py:2: UserWarning: `keep_geom_type=True` in overlay resulted in 117 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries

# %%
# Perform the intersection
meta_lcvoc_2010 = gpd.overlay(lc['meta_cover2010l2'], meta_voc, how="intersection")

# Save the result to a file
output_path = "./data/lc_voc/meta_lcvoc_2010.gpkg"
meta_lcvoc_2010.to_file(output_path, driver="GPKG")
# Out:
# c:\Users\VICTUS\anaconda3\envs\osgeo-env-v1\lib\site-packages\ipykernel_launcher.py:2: UserWarning: `keep_geom_type=True` in overlay resulted in 229 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries

# %%
# Perform the intersection
meta_lcvoc_2018 = gpd.overlay(lc['meta_cover2018l2'], meta_voc, how="intersection")

# Save the result to a file
output_path = "./data/lc_voc/meta_lcvoc_2018.gpkg"
meta_lcvoc_2018.to_file(output_path, driver="GPKG")
# Out:
# c:\Users\VICTUS\anaconda3\envs\osgeo-env-v1\lib\site-packages\ipykernel_launcher.py:2: UserWarning: `keep_geom_type=True` in overlay resulted in 124 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries

# %% [markdown]
# Level 1

# %%
# Input and output folders
covers_dir = "./data/cover/coverl2"
output_folder = "./data/cover/coverl1"
os.makedirs(output_folder, exist_ok=True)

# Mapping dictionary
level_1_mapping = {
    "1": "Artificial surfaces",
    "2": "Agricultural areas",
    "3": "Forest and seminatural areas",
    "4": "Wetlands",
    "5": "Water bodies"
}

# Find all GPKG files
covers_dep_files = glob.glob(os.path.join(covers_dir, "*.gpkg"))

# Dictionary to store new GeoDataFrames
lc1 = {}

# Process each file
for file_path in covers_dep_files:
    # Read file
    gdf = gpd.read_file(file_path)
    
    # Extract first digit and map to level1
    gdf["level1"] = gdf["l2_code"].astype(str).str[0].map(level_1_mapping)
    
    # Keep only desired columns
    gdf = gdf[["level1", "level2", "geometry"]]
    
    # Store in dictionary
    name = os.path.basename(file_path).replace("l2.gpkg", "")
    lc1[name] = gdf
    
    # Save to new folder
    out_path = os.path.join(output_folder, f"{name}l1.gpkg")
    gdf.to_file(out_path, driver="GPKG")
    
    print(f"Processed and saved: {out_path}")
# Out:
# Processed and saved: ./data/cover/coverl1\ara_cover2000l1.gpkg
# Processed and saved: ./data/cover/coverl1\ara_cover2010l1.gpkg
# Processed and saved: ./data/cover/coverl1\ara_cover2018l1.gpkg
# Processed and saved: ./data/cover/coverl1\casa_cover2000l1.gpkg
# Processed and saved: ./data/cover/coverl1\casa_cover2010l1.gpkg
# Processed and saved: ./data/cover/coverl1\casa_cover2018l1.gpkg
# Processed and saved: ./data/cover/coverl1\meta_cover2000l1.gpkg
# Processed and saved: ./data/cover/coverl1\meta_cover2010l1.gpkg
# Processed and saved: ./data/cover/coverl1\meta_cover2018l1.gpkg
